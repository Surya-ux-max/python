# %% [markdown]
#  ## MACHINE LEARNING BASICS
#
#  # Types of Models
#  * Regression
#  * Classification
#  * Clustering

# %% [markdown]
# ## test code for python initialising

# %%
Name = input("Enter your name");
print(Name);

print("Hello " + Name + ", welcome to Python programming!");


age =18;
print(age);
# Out:
# surya
# Hello surya, welcome to Python programming!
# 18

# %% [markdown]
# # 1. REGRESSION
# ### To predict continuous linear values from the given data
# Steps:
# 1. Gather all the required data.
# 2. Define the features(X) with us and target values(Y).
# 3. Use training data to Train the model.
# 4. Use testing data to test model performance
# 5. Visualize the final model.
